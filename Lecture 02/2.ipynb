# %%
b = "Hello, World!"
print(b[2:5])
print(b[:5])
print(b[0:5])
print(b[2:])
print(b[-5:-2])
# Out:
# llo
# Hello
# Hello
# llo, World!
# orl

# %%
a = "Rakibul Asib Redoy"
#print(a.upper())
#print(a.lower())
print(a.title())
print(a.capitalize())
#print(a.swapcase())
# Out:
#  Rakibul Asib Redoy
#  rakibul asib redoy
# Rakibul Asib Redoy

# %%
a = " Rakibul Asib Redoy"
print(a.strip())
# Out:
# Rakibul Asib Redoy

# %%
a = "Rakibul Asib Redoy"
print(a.replace("Asib", "Asif"))
# Out:
# Rakibul Asif Redoy

# %%
a = "Rakibul Asib Redoy"
print(a.split(" "))
# Out:
# ['Rakibul', 'Asib', 'Redoy']

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
age = 23
a = "Rakibul Asib Redoy"
txt = f"My name is {a}, I am {age} years old."
print(txt)
# Out:
# My name is Rakibul Asib Redoy, I am 23 years old.

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
# Single Quote
txt = 'It\'s alright.'
print(txt)
# Out:
# It's alright.

# %%
# Backslash
txt = "This will insert one \\ (backslash)."
print(txt)
# Out:
# This will insert one \ (backslash).

# %%
# New Line
txt = "Hello\nWorld!"
print(txt)
# Out:
# Hello
# World!

# %%
# Carriage Return
txt = "Hello\rWorld!"
print(txt)
# Out:
# World!

# %%
#	Tab
txt = "Hello\tWorld!"
print(txt)
# Out:
# Hello	World!

# %%
# Backspace
txt = "Hello\bWorld!"
print(txt)
# Out:
# World!

# %%
# Form Feed
txt = "Hello\fWorld!"
print(txt)
# Out:
# HelloWorld!

# %%
# Octal value
#A backslash followed by three integers will result in a octal value:
txt = "\110\145\154\154\157"
print(txt)
# Out:
# Hello

# %%
# Hex value
#A backslash followed by an 'x' and a hex number represents a hex value:
txt = "\x48\x65\x6c\x6c\x6f"
print(txt)
# Out:
# Hello
