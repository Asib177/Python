# %%
x = 1j
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
x = ["Apple", "Banana", "Cherry"]
print(x)
print(type(x))
# Out:
# ['Apple', 'Banana', 'Cherry']
# <class 'list'>

# %%
x = ("Apple", "Banana", "Cherry")
print(x)
print(type(x))
# Out:
# ('Apple', 'Banana', 'Cherry')
# <class 'tuple'>

# %%
x = range(6)
print(x)
print(type(x))
# Out:
# range(0, 6)
# <class 'range'>

# %%
x = range(3, 6)
print(x)
print(type(x))
# Out:
# range(3, 6)
# <class 'range'>

# %%
x = {"name": "Asib", "age": 27}
print(x)
print(type(x))
# Out:
# {'name': 'Asib', 'age': 27}
# <class 'dict'>
