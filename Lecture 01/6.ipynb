# %%
a = 33
b = 200

if b > a:
  print("b is greater than a")
else:
  print("a is greater than b")
# Out:
# b is greater than a

# %%
a = 33
b = 33

if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b is equal")
else:
  print("a is greater than b")
# Out:
# a and b is equal

# %%
a = 200
b = 33
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 33
b = 333
print("A") if a > b else print("B")
# Out:
# B

# %%
a = 330
b = 330
print("A") if a > b else print("=") if a < b else print("B") if a != b else print("C") if a == b else print("D")
# Out:
# C

# %%
a = 33
b = 200

if b > a:
  pass
