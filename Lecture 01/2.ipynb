# %%
age = int(input("Enter your age: "))
print(age)
# Out:
# Enter your age: 23
# 23

# %%
print("Were " + "wolf")
print("4" + "man")
print(str(4) + "chan")
# Out:
# Were wolf
# 4man
# 4chan

# %%
print(4 * " Test")
# Out:
#  Test Test Test Test
