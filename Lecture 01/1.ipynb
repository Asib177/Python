# %%
name = input("Give me your name: ")
print("Your name is: " + name)
# Out:
# Give me your name: Asib
# Your name is: Asib

# %%
age = input("Enter your age: ")
print(type(age))
print("Your age is: " + age)
age = int(age)
print(type(age))
age = float(age)
print(type(age))
age = str(age)
print(type(age))
age = bool(age)
print(type(age))
# Out:
# Enter your age: 23
# <class 'str'>
# Your age is: 23
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
