# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys

print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
if 5 > 2:
  print("Five is greater than two.")
# Out:
# Five is greater than two.

# %%
if 5 > 2:
 print("Five is greater than two.")
# Out:
# Five is greater than two.

# %%
if 5 > 2:
  print("Five is greater than two")
  print("Hello Asib")
# Out:
# Five is greater than two
# Hello Asib

# %%
x = 5
y = "Hello, World"

print(x)
print(y)
# Out:
# 5
# Hello, World

# %%
# This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello, World!") # This is a comment
# Out:
# Hello, World!

# %%
"""I am Asib
The student of UIU
I am reading the department of CSE of third year student
"""
print("Hello, World!")
# Out:
# Hello, World!
