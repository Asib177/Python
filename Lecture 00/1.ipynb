# %%
a = 5
print(type(a))
# Out:
# <class 'int'>

# %%
a=5.5
print(type(a))
# Out:
# <class 'float'>

# %%
a="Asib"
print(type(a))
# Out:
# <class 'str'>

# %%
a='''My name is Asib'''
print(type(a))
# Out:
# <class 'str'>

# %%
a='''My name is Asib'''
print(a)
# Out:
# My name is Asib

# %%
a='''My name is
Asib'''
print(a)
# Out:
# My name is
# Asib
